# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import shutil

# %%
os.environ['KAGGLE_CONFIG_DIR']="/content"

# %%
# !kaggle datasets download -d paultimothymooney/chest-xray-pneumonia
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /content/kaggle.json'
# Downloading chest-xray-pneumonia.zip to /content
#  99% 2.27G/2.29G [01:12<00:01, 26.7MB/s]
# 100% 2.29G/2.29G [01:12<00:00, 33.8MB/s]

# %%
shutil.copy2('/content/drive/My Drive/Untitled folder/Dataset.zip','.')
# Out:
# './Dataset.zip'

# %%
from zipfile import ZipFile
fname='/content/Dataset.zip'
with ZipFile(fname,'r') as zip:
  zip.extractall()
  print('done')

fname='/content/chest-xray-pneumonia.zip'
with ZipFile(fname,'r') as zip:
  zip.extractall()
  print('done')
# Out:
# done
# done

# %%
os.mkdir('dataset')
shutil.move('/content/covid','dataset')
shutil.move('/content/chest_xray/train/NORMAL','dataset')
# Out:
# 'dataset/NORMAL'

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input,Lambda,Dense,Flatten,AveragePooling2D,Dropout
from tensorflow.keras.models import Model,load_model
from tensorflow.keras.applications import VGG16
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import confusion_matrix,roc_curve,accuracy_score
import cv2
import numpy as np
import matplotlib.pyplot as plt
from glob import glob

# %%
IMAGE_SIZE=[224,224]

epochs=50
batch_size=32

covid_path='/content/dataset/covid'
normal_path='/content/dataset/NORMAL'
# pneumonia_path='/content/dataset/PNEUMONIA'

covid_files=glob(covid_path+'/*')
normal_files=glob(normal_path+'/*')
# pneumonia_files=glob(normal_path+'/*')

# %%
covid_labels=[]
normal_labels=[]
# pneumonia_labels=[]

covid_images=[]
normal_images=[]
# pneumonia_images=[]

import cv2
for i in range(len(covid_files)):
  image=cv2.imread(covid_files[i])
  image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
  image=cv2.resize(image,(224,224))
  covid_images.append(image)
  covid_labels.append('covid')

for i in range(700):
  image=cv2.imread(normal_files[i])
  image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
  image=cv2.resize(image,(224,224))
  normal_images.append(image)
  normal_labels.append('normal')

# for i in range(500):
#   image=cv2.imread(pneumonia_files[i])
#   image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
#   image=cv2.resize(image,(224,224))
#   pneumonia_images.append(image)
#   pneumonia_labels.append('pneumonia')

# %%
def plot_images(images, title):
    nrows, ncols = 5, 8
    figsize = [10, 6]

    fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=figsize, facecolor=(1, 1, 1))

    for i, axi in enumerate(ax.flat):
        axi.imshow(images[i])
        axi.set_axis_off()

    plt.suptitle(title, fontsize=24)
    plt.tight_layout(pad=0.2, rect=[0, 0, 1, 0.9])
    plt.show()
plot_images(covid_images, 'Positive COVID-19 Chest X-ray')
plot_images(normal_images, 'Normal Chest X-ray')

# %%
#normalize to (0,1)
covid_images=np.array(covid_images)/255.0
normal_images=np.array(normal_images)/255.0
# pneumonia_images=np.array(pneumonia_images)/255.0

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras.utils import to_categorical

#split to train,test
covid_x_train,covid_x_test,covid_y_train,covid_y_test=train_test_split(covid_images,covid_labels,test_size=.2)
normal_x_train,normal_x_test,normal_y_train,normal_y_test=train_test_split(normal_images,normal_labels,test_size=.2)
# pneumonia_x_train,pneumonia_x_test,pneumonia_y_train,pneumonia_y_test=train_test_split(pneumonia_images,pneumonia_labels,test_size=.2)

# X_train=np.concatenate((pneumonia_x_train,normal_x_train,covid_x_train),axis=0)
# X_test=np.concatenate((pneumonia_x_test,normal_x_test,covid_x_test),axis=0)
# Y_train=np.concatenate((pneumonia_y_train,normal_y_train,covid_y_train),axis=0)
# Y_test=np.concatenate((pneumonia_y_test,normal_y_test,covid_y_test),axis=0)


X_train=np.concatenate((normal_x_train,covid_x_train),axis=0)
X_test=np.concatenate((normal_x_test,covid_x_test),axis=0)
Y_train=np.concatenate((normal_y_train,covid_y_train),axis=0)
Y_test=np.concatenate((normal_y_test,covid_y_test),axis=0)

# %%
Y_train=LabelBinarizer().fit_transform(Y_train)
Y_train=to_categorical(Y_train)

Y_test=LabelBinarizer().fit_transform(Y_test)
Y_test=to_categorical(Y_test)

# %%
vgg16=VGG16(weights='imagenet',include_top=False,input_tensor=Input(shape=(224,224,3)))

outputs=vgg16.output
outputs=AveragePooling2D(pool_size=(4,4))(outputs)
outputs=Dropout(.5)(outputs)
outputs=Flatten(name='flattern')(outputs)
outputs=Dropout(.5)(outputs)
outputs=Dense(64,activation='relu')(outputs)
outputs=Dropout(.5)(outputs)
outputs=Dense(2,activation='softmax')(outputs)

model=Model(inputs=vgg16.input,outputs=outputs)

for layer in vgg16.layers:
  layer.trainable=False

model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

train_aug=ImageDataGenerator(
    rotation_range=20,
    width_shift_range=.2,
    height_shift_range=.2,
    horizontal_flip=True
)

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint('model.h5', verbose=1, monitor='loss',save_best_only=True, mode='auto')

# %%
history=model.fit(train_aug.flow(X_train,Y_train,batch_size=32),
                  validation_data=(X_test,Y_test),
                  validation_steps=len(X_test)/32,
                  steps_per_epoch=len(X_train)/32,
                  callbacks=[checkpoint],
                  epochs=70
)
# Out:
# Epoch 1/70
# 29/28 [==============================] - ETA: 0s - loss: 0.9152 - accuracy: 0.5524
# Epoch 00001: loss improved from inf to 0.91516, saving model to model.h5
# 29/28 [==============================] - 10s 344ms/step - loss: 0.9152 - accuracy: 0.5524 - val_loss: 0.5369 - val_accuracy: 0.9174
# Epoch 2/70
# 29/28 [==============================] - ETA: 0s - loss: 0.7398 - accuracy: 0.6190
# Epoch 00002: loss improved from 0.91516 to 0.73981, saving model to model.h5
# 29/28 [==============================] - 9s 326ms/step - loss: 0.7398 - accuracy: 0.6190 - val_loss: 0.5171 - val_accuracy: 0.9087
# Epoch 3/70
# 29/28 [==============================] - ETA: 0s - loss: 0.5908 - accuracy: 0.6932
# Epoch 00003: loss improved from 0.73981 to 0.59078, saving model to model.h5
# 29/28 [==============================] - 9s 323ms/step - loss: 0.5908 - accuracy: 0.6932 - val_loss: 0.4748 - val_accuracy: 0.9000
# Epoch 4/70
# 29/28 [==============================] - ETA: 0s - loss: 0.5806 - accuracy: 0.7151
# Epoch 00004: loss improved from 0.59078 to 0.58058, saving model to model.h5
# 29/28 [==============================] - 9s 324ms/step - loss: 0.5806 - accuracy: 0.7151 - val_loss: 0.4499 - val_accuracy: 0.9000
# Epoch 5/70
# 29/28 [==============================] - ETA: 0s - loss: 0.5335 - accuracy: 0.7369
# Epoch 00005: loss improved from 0.58058 to 0.53353, saving model to model.h5
# 29/28 [==============================] - 10s 332ms/step - loss: 0.5335 - accuracy: 0.7369 - val_loss: 0.4194 - val_accuracy: 0.8739
# Epoch 6/70
# 29/28 [==============================] - ETA: 0s - loss: 0.5035 - accuracy: 0.7631
# Epoch 00006: loss improved from 0.53353 to 0.50349, saving model to model.h5
# 29/28 [==============================] - 9s 324ms/step - loss: 0.5035 - accuracy: 0.7631 - val_loss: 0.3871 - val_accuracy: 0.8913
# Epoch 7/70
# 29/28 [==============================] - ETA: 0s - loss: 0.4906 - accuracy: 0.7620
# Epoch 00007: loss improved from 0.50349 to 0.49057, saving model to model.h5
# 29/28 [==============================] - 10s 328ms/step - loss: 0.4906 - accuracy: 0.7620 - val_loss: 0.3428 - val_accuracy: 0.9174
# Epoch 8/70
# 29/28 [==============================] - ETA: 0s - loss: 0.4885 - accuracy: 0.7773
# Epoch 00008: loss improved from 0.49057 to 0.48855, saving model to model.h5
# 29/28 [==============================] - 9s 325ms/step - loss: 0.4885 - accuracy: 0.7773 - val_loss: 0.3186 - val_accuracy: 0.9217
# Epoch 9/70
# 29/28 [==============================] - ETA: 0s - loss: 0.4482 - accuracy: 0.7849
# Epoch 00009: loss improved from 0.48855 to 0.44821, saving model to model.h5
# 29/28 [==============================] - 9s 324ms/step - loss: 0.4482 - accuracy: 0.7849 - val_loss: 0.3350 - val_accuracy: 0.8870
# Epoch 10/70
# 29/28 [==============================] - ETA: 0s - loss: 0.4371 - accuracy: 0.7904
# Epoch 00010: loss improved from 0.44821 to 0.43709, saving model to model.h5
# 29/28 [==============================] - 9s 324ms/step - loss: 0.4371 - accuracy: 0.7904 - val_loss: 0.2898 - val_accuracy: 0.9217
# Epoch 11/70
# 29/28 [==============================] - ETA: 0s - loss: 0.4405 - accuracy: 0.8122
# Epoch 00011: loss did not improve from 0.43709
# 29/28 [==============================] - 9s 322ms/step - loss: 0.4405 - accuracy: 0.8122 - val_loss: 0.2843 - val_accuracy: 0.9174
# Epoch 12/70
# 29/28 [==============================] - ETA: 0s - loss: 0.4217 - accuracy: 0.8090
# Epoch 00012: loss improved from 0.43709 to 0.42165, saving model to model.h5
# 29/28 [==============================] - 9s 325ms/step - loss: 0.4217 - accuracy: 0.8090 - val_loss: 0.2550 - val_accuracy: 0.9261
# Epoch 13/70
# 29/28 [==============================] - ETA: 0s - loss: 0.4379 - accuracy: 0.8002
# Epoch 00013: loss did not improve from 0.42165
# 29/28 [==============================] - 9s 319ms/step - loss: 0.4379 - accuracy: 0.8002 - val_loss: 0.2592 - val_accuracy: 0.9174
# Epoch 14/70
# 29/28 [==============================] - ETA: 0s - loss: 0.4057 - accuracy: 0.8297
# Epoch 00014: loss improved from 0.42165 to 0.40569, saving model to model.h5
# 29/28 [==============================] - 9s 321ms/step - loss: 0.4057 - accuracy: 0.8297 - val_loss: 0.2547 - val_accuracy: 0.9261
# Epoch 15/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3886 - accuracy: 0.8221
# Epoch 00015: loss improved from 0.40569 to 0.38856, saving model to model.h5
# 29/28 [==============================] - 9s 323ms/step - loss: 0.3886 - accuracy: 0.8221 - val_loss: 0.2495 - val_accuracy: 0.9174
# Epoch 16/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3907 - accuracy: 0.8352
# Epoch 00016: loss did not improve from 0.38856
# 29/28 [==============================] - 9s 319ms/step - loss: 0.3907 - accuracy: 0.8352 - val_loss: 0.2449 - val_accuracy: 0.9174
# Epoch 17/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3802 - accuracy: 0.8406
# Epoch 00017: loss improved from 0.38856 to 0.38016, saving model to model.h5
# 29/28 [==============================] - 9s 322ms/step - loss: 0.3802 - accuracy: 0.8406 - val_loss: 0.2633 - val_accuracy: 0.9130
# Epoch 18/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3778 - accuracy: 0.8352
# Epoch 00018: loss improved from 0.38016 to 0.37780, saving model to model.h5
# 29/28 [==============================] - 9s 326ms/step - loss: 0.3778 - accuracy: 0.8352 - val_loss: 0.2367 - val_accuracy: 0.9174
# Epoch 19/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3727 - accuracy: 0.8417
# Epoch 00019: loss improved from 0.37780 to 0.37271, saving model to model.h5
# 29/28 [==============================] - 9s 323ms/step - loss: 0.3727 - accuracy: 0.8417 - val_loss: 0.2326 - val_accuracy: 0.9174
# Epoch 20/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3572 - accuracy: 0.8439
# Epoch 00020: loss improved from 0.37271 to 0.35721, saving model to model.h5
# 29/28 [==============================] - 9s 324ms/step - loss: 0.3572 - accuracy: 0.8439 - val_loss: 0.2155 - val_accuracy: 0.9217
# Epoch 21/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3568 - accuracy: 0.8417
# Epoch 00021: loss improved from 0.35721 to 0.35676, saving model to model.h5
# 29/28 [==============================] - 9s 324ms/step - loss: 0.3568 - accuracy: 0.8417 - val_loss: 0.2327 - val_accuracy: 0.9174
# Epoch 22/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3378 - accuracy: 0.8592
# Epoch 00022: loss improved from 0.35676 to 0.33780, saving model to model.h5
# 29/28 [==============================] - 9s 323ms/step - loss: 0.3378 - accuracy: 0.8592 - val_loss: 0.2044 - val_accuracy: 0.9217
# Epoch 23/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3965 - accuracy: 0.8384
# Epoch 00023: loss did not improve from 0.33780
# 29/28 [==============================] - 9s 320ms/step - loss: 0.3965 - accuracy: 0.8384 - val_loss: 0.2183 - val_accuracy: 0.9261
# Epoch 24/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3553 - accuracy: 0.8450
# Epoch 00024: loss did not improve from 0.33780
# 29/28 [==============================] - 9s 318ms/step - loss: 0.3553 - accuracy: 0.8450 - val_loss: 0.2358 - val_accuracy: 0.9174
# Epoch 25/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3432 - accuracy: 0.8472
# Epoch 00025: loss did not improve from 0.33780
# 29/28 [==============================] - 9s 316ms/step - loss: 0.3432 - accuracy: 0.8472 - val_loss: 0.2133 - val_accuracy: 0.9261
# Epoch 26/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3465 - accuracy: 0.8603
# Epoch 00026: loss did not improve from 0.33780
# 29/28 [==============================] - 9s 318ms/step - loss: 0.3465 - accuracy: 0.8603 - val_loss: 0.2228 - val_accuracy: 0.9174
# Epoch 27/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3177 - accuracy: 0.8690
# Epoch 00027: loss improved from 0.33780 to 0.31770, saving model to model.h5
# 29/28 [==============================] - 9s 325ms/step - loss: 0.3177 - accuracy: 0.8690 - val_loss: 0.2135 - val_accuracy: 0.9217
# Epoch 28/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3393 - accuracy: 0.8668
# Epoch 00028: loss did not improve from 0.31770
# 29/28 [==============================] - 9s 319ms/step - loss: 0.3393 - accuracy: 0.8668 - val_loss: 0.2158 - val_accuracy: 0.9217
# Epoch 29/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3297 - accuracy: 0.8570
# Epoch 00029: loss did not improve from 0.31770
# 29/28 [==============================] - 9s 317ms/step - loss: 0.3297 - accuracy: 0.8570 - val_loss: 0.2106 - val_accuracy: 0.9217
# Epoch 30/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3210 - accuracy: 0.8745
# Epoch 00030: loss did not improve from 0.31770
# 29/28 [==============================] - 9s 317ms/step - loss: 0.3210 - accuracy: 0.8745 - val_loss: 0.1979 - val_accuracy: 0.9217
# Epoch 31/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3350 - accuracy: 0.8657
# Epoch 00031: loss did not improve from 0.31770
# 29/28 [==============================] - 9s 321ms/step - loss: 0.3350 - accuracy: 0.8657 - val_loss: 0.2045 - val_accuracy: 0.9217
# Epoch 32/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3420 - accuracy: 0.8472
# Epoch 00032: loss did not improve from 0.31770
# 29/28 [==============================] - 9s 317ms/step - loss: 0.3420 - accuracy: 0.8472 - val_loss: 0.2088 - val_accuracy: 0.9217
# Epoch 33/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3198 - accuracy: 0.8559
# Epoch 00033: loss did not improve from 0.31770
# 29/28 [==============================] - 9s 317ms/step - loss: 0.3198 - accuracy: 0.8559 - val_loss: 0.1957 - val_accuracy: 0.9304
# Epoch 34/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3381 - accuracy: 0.8570
# Epoch 00034: loss did not improve from 0.31770
# 29/28 [==============================] - 9s 318ms/step - loss: 0.3381 - accuracy: 0.8570 - val_loss: 0.2021 - val_accuracy: 0.9217
# Epoch 35/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3189 - accuracy: 0.8712
# Epoch 00035: loss did not improve from 0.31770
# 29/28 [==============================] - 9s 319ms/step - loss: 0.3189 - accuracy: 0.8712 - val_loss: 0.2010 - val_accuracy: 0.9217
# Epoch 36/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3268 - accuracy: 0.8526
# Epoch 00036: loss did not improve from 0.31770
# 29/28 [==============================] - 9s 320ms/step - loss: 0.3268 - accuracy: 0.8526 - val_loss: 0.1958 - val_accuracy: 0.9217
# Epoch 37/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3232 - accuracy: 0.8592
# Epoch 00037: loss did not improve from 0.31770
# 29/28 [==============================] - 9s 324ms/step - loss: 0.3232 - accuracy: 0.8592 - val_loss: 0.2022 - val_accuracy: 0.9261
# Epoch 38/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3248 - accuracy: 0.8548
# Epoch 00038: loss did not improve from 0.31770
# 29/28 [==============================] - 9s 320ms/step - loss: 0.3248 - accuracy: 0.8548 - val_loss: 0.2018 - val_accuracy: 0.9217
# Epoch 39/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3105 - accuracy: 0.8614
# Epoch 00039: loss improved from 0.31770 to 0.31051, saving model to model.h5
# 29/28 [==============================] - 9s 324ms/step - loss: 0.3105 - accuracy: 0.8614 - val_loss: 0.1827 - val_accuracy: 0.9261
# Epoch 40/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3348 - accuracy: 0.8668
# Epoch 00040: loss did not improve from 0.31051
# 29/28 [==============================] - 9s 318ms/step - loss: 0.3348 - accuracy: 0.8668 - val_loss: 0.1975 - val_accuracy: 0.9304
# Epoch 41/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3135 - accuracy: 0.8679
# Epoch 00041: loss did not improve from 0.31051
# 29/28 [==============================] - 9s 317ms/step - loss: 0.3135 - accuracy: 0.8679 - val_loss: 0.1932 - val_accuracy: 0.9261
# Epoch 42/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3178 - accuracy: 0.8603
# Epoch 00042: loss did not improve from 0.31051
# 29/28 [==============================] - 9s 316ms/step - loss: 0.3178 - accuracy: 0.8603 - val_loss: 0.1854 - val_accuracy: 0.9261
# Epoch 43/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3032 - accuracy: 0.8832
# Epoch 00043: loss improved from 0.31051 to 0.30323, saving model to model.h5
# 29/28 [==============================] - 9s 323ms/step - loss: 0.3032 - accuracy: 0.8832 - val_loss: 0.1837 - val_accuracy: 0.9261
# Epoch 44/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3082 - accuracy: 0.8745
# Epoch 00044: loss did not improve from 0.30323
# 29/28 [==============================] - 9s 320ms/step - loss: 0.3082 - accuracy: 0.8745 - val_loss: 0.1827 - val_accuracy: 0.9261
# Epoch 45/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3188 - accuracy: 0.8603
# Epoch 00045: loss did not improve from 0.30323
# 29/28 [==============================] - 9s 319ms/step - loss: 0.3188 - accuracy: 0.8603 - val_loss: 0.1797 - val_accuracy: 0.9304
# Epoch 46/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3105 - accuracy: 0.8701
# Epoch 00046: loss did not improve from 0.30323
# 29/28 [==============================] - 9s 319ms/step - loss: 0.3105 - accuracy: 0.8701 - val_loss: 0.1921 - val_accuracy: 0.9174
# Epoch 47/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3317 - accuracy: 0.8777
# Epoch 00047: loss did not improve from 0.30323
# 29/28 [==============================] - 9s 317ms/step - loss: 0.3317 - accuracy: 0.8777 - val_loss: 0.1724 - val_accuracy: 0.9304
# Epoch 48/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3369 - accuracy: 0.8745
# Epoch 00048: loss did not improve from 0.30323
# 29/28 [==============================] - 9s 319ms/step - loss: 0.3369 - accuracy: 0.8745 - val_loss: 0.2038 - val_accuracy: 0.9174
# Epoch 49/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3080 - accuracy: 0.8690
# Epoch 00049: loss did not improve from 0.30323
# 29/28 [==============================] - 9s 318ms/step - loss: 0.3080 - accuracy: 0.8690 - val_loss: 0.1820 - val_accuracy: 0.9348
# Epoch 50/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3155 - accuracy: 0.8865
# Epoch 00050: loss did not improve from 0.30323
# 29/28 [==============================] - 9s 317ms/step - loss: 0.3155 - accuracy: 0.8865 - val_loss: 0.1902 - val_accuracy: 0.9217
# Epoch 51/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3125 - accuracy: 0.8788
# Epoch 00051: loss did not improve from 0.30323
# 29/28 [==============================] - 9s 318ms/step - loss: 0.3125 - accuracy: 0.8788 - val_loss: 0.1889 - val_accuracy: 0.9217
# Epoch 52/70
# 29/28 [==============================] - ETA: 0s - loss: 0.2905 - accuracy: 0.8701
# Epoch 00052: loss improved from 0.30323 to 0.29050, saving model to model.h5
# 29/28 [==============================] - 9s 324ms/step - loss: 0.2905 - accuracy: 0.8701 - val_loss: 0.1836 - val_accuracy: 0.9217
# Epoch 53/70
# 29/28 [==============================] - ETA: 0s - loss: 0.2957 - accuracy: 0.8712
# Epoch 00053: loss did not improve from 0.29050
# 29/28 [==============================] - 9s 319ms/step - loss: 0.2957 - accuracy: 0.8712 - val_loss: 0.1821 - val_accuracy: 0.9217
# Epoch 54/70
# 29/28 [==============================] - ETA: 0s - loss: 0.2955 - accuracy: 0.8690
# Epoch 00054: loss did not improve from 0.29050
# 29/28 [==============================] - 9s 318ms/step - loss: 0.2955 - accuracy: 0.8690 - val_loss: 0.1940 - val_accuracy: 0.9217
# Epoch 55/70
# 29/28 [==============================] - ETA: 0s - loss: 0.2822 - accuracy: 0.8876
# Epoch 00055: loss improved from 0.29050 to 0.28224, saving model to model.h5
# 29/28 [==============================] - 9s 322ms/step - loss: 0.2822 - accuracy: 0.8876 - val_loss: 0.1792 - val_accuracy: 0.9217
# Epoch 56/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3241 - accuracy: 0.8657
# Epoch 00056: loss did not improve from 0.28224
# 29/28 [==============================] - 9s 319ms/step - loss: 0.3241 - accuracy: 0.8657 - val_loss: 0.1716 - val_accuracy: 0.9348
# Epoch 57/70
# 29/28 [==============================] - ETA: 0s - loss: 0.2862 - accuracy: 0.8766
# Epoch 00057: loss did not improve from 0.28224
# 29/28 [==============================] - 9s 318ms/step - loss: 0.2862 - accuracy: 0.8766 - val_loss: 0.1751 - val_accuracy: 0.9348
# Epoch 58/70
# 29/28 [==============================] - ETA: 0s - loss: 0.2887 - accuracy: 0.8788
# Epoch 00058: loss did not improve from 0.28224
# 29/28 [==============================] - 9s 317ms/step - loss: 0.2887 - accuracy: 0.8788 - val_loss: 0.1749 - val_accuracy: 0.9304
# Epoch 59/70
# 29/28 [==============================] - ETA: 0s - loss: 0.2848 - accuracy: 0.8876
# Epoch 00059: loss did not improve from 0.28224
# 29/28 [==============================] - 9s 318ms/step - loss: 0.2848 - accuracy: 0.8876 - val_loss: 0.1656 - val_accuracy: 0.9348
# Epoch 60/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3121 - accuracy: 0.8766
# Epoch 00060: loss did not improve from 0.28224
# 29/28 [==============================] - 9s 318ms/step - loss: 0.3121 - accuracy: 0.8766 - val_loss: 0.1873 - val_accuracy: 0.9217
# Epoch 61/70
# 29/28 [==============================] - ETA: 0s - loss: 0.2753 - accuracy: 0.8930
# Epoch 00061: loss improved from 0.28224 to 0.27527, saving model to model.h5
# 29/28 [==============================] - 9s 320ms/step - loss: 0.2753 - accuracy: 0.8930 - val_loss: 0.1690 - val_accuracy: 0.9348
# Epoch 62/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3043 - accuracy: 0.8690
# Epoch 00062: loss did not improve from 0.27527
# 29/28 [==============================] - 9s 320ms/step - loss: 0.3043 - accuracy: 0.8690 - val_loss: 0.1670 - val_accuracy: 0.9304
# Epoch 63/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3000 - accuracy: 0.8690
# Epoch 00063: loss did not improve from 0.27527
# 29/28 [==============================] - 9s 316ms/step - loss: 0.3000 - accuracy: 0.8690 - val_loss: 0.1852 - val_accuracy: 0.9217
# Epoch 64/70
# 29/28 [==============================] - ETA: 0s - loss: 0.2894 - accuracy: 0.8788
# Epoch 00064: loss did not improve from 0.27527
# 29/28 [==============================] - 9s 321ms/step - loss: 0.2894 - accuracy: 0.8788 - val_loss: 0.1803 - val_accuracy: 0.9217
# Epoch 65/70
# 29/28 [==============================] - ETA: 0s - loss: 0.2786 - accuracy: 0.8865
# Epoch 00065: loss did not improve from 0.27527
# 29/28 [==============================] - 9s 316ms/step - loss: 0.2786 - accuracy: 0.8865 - val_loss: 0.1684 - val_accuracy: 0.9348
# Epoch 66/70
# 29/28 [==============================] - ETA: 0s - loss: 0.2732 - accuracy: 0.8886
# Epoch 00066: loss improved from 0.27527 to 0.27319, saving model to model.h5
# 29/28 [==============================] - 9s 321ms/step - loss: 0.2732 - accuracy: 0.8886 - val_loss: 0.1681 - val_accuracy: 0.9261
# Epoch 67/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3071 - accuracy: 0.8723
# Epoch 00067: loss did not improve from 0.27319
# 29/28 [==============================] - 9s 317ms/step - loss: 0.3071 - accuracy: 0.8723 - val_loss: 0.1727 - val_accuracy: 0.9261
# Epoch 68/70
# 29/28 [==============================] - ETA: 0s - loss: 0.2762 - accuracy: 0.8679
# Epoch 00068: loss did not improve from 0.27319
# 29/28 [==============================] - 9s 319ms/step - loss: 0.2762 - accuracy: 0.8679 - val_loss: 0.1780 - val_accuracy: 0.9304
# Epoch 69/70
# 29/28 [==============================] - ETA: 0s - loss: 0.2765 - accuracy: 0.8821
# Epoch 00069: loss did not improve from 0.27319
# 29/28 [==============================] - 9s 325ms/step - loss: 0.2765 - accuracy: 0.8821 - val_loss: 0.1743 - val_accuracy: 0.9261
# Epoch 70/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3003 - accuracy: 0.8734
# Epoch 00070: loss did not improve from 0.27319
# 29/28 [==============================] - 9s 321ms/step - loss: 0.3003 - accuracy: 0.8734 - val_loss: 0.1759 - val_accuracy: 0.9261

# %%
#load saved model
model=load_model('model.h5')

# %%
y_pred=model.predict(X_test,batch_size=32)

# %%
prediction=y_pred[0:10]
for index, probability in enumerate(prediction):
  if probability[1] > 0.5:
        plt.title('%.2f' % (probability[1]*100) + '% NonCOVID')
  else:
        plt.title('%.2f' % ((1-probability[1])*100) + '% COVID')
  plt.imshow(X_test[index])
  plt.show()

# %%
y_pred_bin = np.argmax(y_pred, axis=1)
y_test_bin = np.argmax(Y_test, axis=1)

# %%
import seaborn as sns
def plot_confusion_matrix(normalize):
  classes = ['COVID','NonCOVID']
  tick_marks = [0.5,1.5]
  cn = confusion_matrix(y_test_bin, y_pred_bin,normalize=normalize)
  sns.heatmap(cn,cmap='plasma',annot=True)
  plt.xticks(tick_marks, classes)
  plt.yticks(tick_marks, classes)
  plt.title('Confusion Matrix')
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.show()

print('Confusion Matrix without Normalization')
plot_confusion_matrix(normalize=None)

print('Confusion Matrix with Normalized Values')
plot_confusion_matrix(normalize='true')
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Confusion Matrix without Normalization
# Confusion Matrix with Normalized Values

# %%
fpr, tpr, thresholds = roc_curve(y_test_bin, y_pred_bin)
plt.plot(fpr, tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.rcParams['font.size'] = 12
plt.title('ROC curve for our model')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid(True)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test_bin, y_pred_bin))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.82      0.90        90
#            1       0.90      0.99      0.94       140
#
#     accuracy                           0.93       230
#    macro avg       0.94      0.91      0.92       230
# weighted avg       0.93      0.93      0.92       230

# %%
plt.figure(figsize=(10,10))

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])
plt.show()

# %%
plt.figure(figsize=(10,10))

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])
plt.savefig('vgg_chest_loss.png')
plt.show()

# %%
shutil.copy2('/content/model.h5','/content/drive/My Drive/Untitled folder')
# Out:
# '/content/drive/My Drive/Untitled folder/model.h5'

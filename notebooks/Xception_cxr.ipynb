# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import shutil

# %%
os.environ['KAGGLE_CONFIG_DIR']="/content"

# %%
# !kaggle datasets download -d paultimothymooney/chest-xray-pneumonia
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /content/kaggle.json'
# Downloading chest-xray-pneumonia.zip to /content
#  99% 2.28G/2.29G [00:49<00:00, 36.8MB/s]
# 100% 2.29G/2.29G [00:49<00:00, 49.5MB/s]

# %%
shutil.copy2('/content/drive/My Drive/Untitled folder/Dataset.zip','.')
# Out:
# './Dataset.zip'

# %%
from zipfile import ZipFile
fname='/content/Dataset.zip'
with ZipFile(fname,'r') as zip:
  zip.extractall()
  print('done')

fname='/content/chest-xray-pneumonia.zip'
with ZipFile(fname,'r') as zip:
  zip.extractall()
  print('done')
# Out:
# done
# done

# %%
os.mkdir('dataset')
shutil.move('/content/covid','dataset')
shutil.move('/content/chest_xray/train/NORMAL','dataset')
# Out:
# 'dataset/NORMAL'

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input,Lambda,Dense,Flatten,AveragePooling2D,Dropout
from tensorflow.keras.models import Model,load_model
from tensorflow.keras.applications import Xception
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import confusion_matrix,roc_curve,accuracy_score
import cv2
import numpy as np
import matplotlib.pyplot as plt
from glob import glob

# %%
IMAGE_SIZE=[224,224]

epochs=50
batch_size=32

covid_path='/content/dataset/covid'
normal_path='/content/dataset/NORMAL'
# pneumonia_path='/content/dataset/PNEUMONIA'

covid_files=glob(covid_path+'/*')
normal_files=glob(normal_path+'/*')
# pneumonia_files=glob(normal_path+'/*')

# %%
covid_labels=[]
normal_labels=[]
# pneumonia_labels=[]

covid_images=[]
normal_images=[]
# pneumonia_images=[]

import cv2
for i in range(len(covid_files)):
  image=cv2.imread(covid_files[i])
  image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
  image=cv2.resize(image,(224,224))
  covid_images.append(image)
  covid_labels.append('covid')

for i in range(700):
  image=cv2.imread(normal_files[i])
  image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
  image=cv2.resize(image,(224,224))
  normal_images.append(image)
  normal_labels.append('normal')

# for i in range(500):
#   image=cv2.imread(pneumonia_files[i])
#   image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
#   image=cv2.resize(image,(224,224))
#   pneumonia_images.append(image)
#   pneumonia_labels.append('pneumonia')

# %%
def plot_images(images, title):
    nrows, ncols = 5, 8
    figsize = [10, 6]

    fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=figsize, facecolor=(1, 1, 1))

    for i, axi in enumerate(ax.flat):
        axi.imshow(images[i])
        axi.set_axis_off()

    plt.suptitle(title, fontsize=24)
    plt.tight_layout(pad=0.2, rect=[0, 0, 1, 0.9])
    plt.show()
plot_images(covid_images, 'Positive COVID-19 Chest X-ray')
plot_images(normal_images, 'Normal Chest X-ray')

# %%
#normalize to (0,1)
covid_images=np.array(covid_images)/255.0
normal_images=np.array(normal_images)/255.0
# pneumonia_images=np.array(pneumonia_images)/255.0

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras.utils import to_categorical

#split to train,test
covid_x_train,covid_x_test,covid_y_train,covid_y_test=train_test_split(covid_images,covid_labels,test_size=.2)
normal_x_train,normal_x_test,normal_y_train,normal_y_test=train_test_split(normal_images,normal_labels,test_size=.2)
# pneumonia_x_train,pneumonia_x_test,pneumonia_y_train,pneumonia_y_test=train_test_split(pneumonia_images,pneumonia_labels,test_size=.2)

# X_train=np.concatenate((pneumonia_x_train,normal_x_train,covid_x_train),axis=0)
# X_test=np.concatenate((pneumonia_x_test,normal_x_test,covid_x_test),axis=0)
# Y_train=np.concatenate((pneumonia_y_train,normal_y_train,covid_y_train),axis=0)
# Y_test=np.concatenate((pneumonia_y_test,normal_y_test,covid_y_test),axis=0)


X_train=np.concatenate((normal_x_train,covid_x_train),axis=0)
X_test=np.concatenate((normal_x_test,covid_x_test),axis=0)
Y_train=np.concatenate((normal_y_train,covid_y_train),axis=0)
Y_test=np.concatenate((normal_y_test,covid_y_test),axis=0)

# %%
Y_train=LabelBinarizer().fit_transform(Y_train)
Y_train=to_categorical(Y_train)

Y_test=LabelBinarizer().fit_transform(Y_test)
Y_test=to_categorical(Y_test)

# %%
xce=Xception(weights='imagenet',include_top=False,input_tensor=Input(shape=(224,224,3)))

outputs=xce.output
outputs=AveragePooling2D(pool_size=(4,4))(outputs)
outputs=Dropout(.5)(outputs)
outputs=Flatten(name='flattern')(outputs)
outputs=Dense(64,activation='relu')(outputs)
outputs=Dropout(.5)(outputs)
outputs=Dense(2,activation='softmax')(outputs)

model=Model(inputs=xce.input,outputs=outputs)

for layer in xce.layers:
  layer.trainable=False

model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

train_aug=ImageDataGenerator(
    rotation_range=20,
    width_shift_range=.2,
    height_shift_range=.2,
    horizontal_flip=True
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 3s 0us/step

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint('model.h5', verbose=1, monitor='loss',save_best_only=True, mode='auto')
# tb=tf.keras.callbacks.TensorBoard(log_dir='.')

# %%
history=model.fit(train_aug.flow(X_train,Y_train,batch_size=32),
                  validation_data=(X_test,Y_test),
                  validation_steps=len(X_test)/32,
                  steps_per_epoch=len(X_train)/32,
                  callbacks=[checkpoint],
                  epochs=70
)
# Out:
# Epoch 1/70
# 29/28 [==============================] - ETA: 0s - loss: 0.3071 - accuracy: 0.8745
# Epoch 00001: loss improved from inf to 0.30705, saving model to model.h5
# 29/28 [==============================] - 18s 633ms/step - loss: 0.3071 - accuracy: 0.8745 - val_loss: 0.1893 - val_accuracy: 0.9391
# Epoch 2/70
# 29/28 [==============================] - ETA: 0s - loss: 0.1166 - accuracy: 0.9563
# Epoch 00002: loss improved from 0.30705 to 0.11665, saving model to model.h5
# 29/28 [==============================] - 16s 554ms/step - loss: 0.1166 - accuracy: 0.9563 - val_loss: 0.1118 - val_accuracy: 0.9522
# Epoch 3/70
# 29/28 [==============================] - ETA: 0s - loss: 0.1435 - accuracy: 0.9585
# Epoch 00003: loss did not improve from 0.11665
# 29/28 [==============================] - 16s 541ms/step - loss: 0.1435 - accuracy: 0.9585 - val_loss: 0.0975 - val_accuracy: 0.9565
# Epoch 4/70
# 29/28 [==============================] - ETA: 0s - loss: 0.1131 - accuracy: 0.9640
# Epoch 00004: loss improved from 0.11665 to 0.11308, saving model to model.h5
# 29/28 [==============================] - 16s 551ms/step - loss: 0.1131 - accuracy: 0.9640 - val_loss: 0.1049 - val_accuracy: 0.9522
# Epoch 5/70
# 29/28 [==============================] - ETA: 0s - loss: 0.1146 - accuracy: 0.9585
# Epoch 00005: loss did not improve from 0.11308
# 29/28 [==============================] - 16s 535ms/step - loss: 0.1146 - accuracy: 0.9585 - val_loss: 0.0762 - val_accuracy: 0.9652
# Epoch 6/70
# 29/28 [==============================] - ETA: 0s - loss: 0.1114 - accuracy: 0.9629
# Epoch 00006: loss improved from 0.11308 to 0.11139, saving model to model.h5
# 29/28 [==============================] - 16s 551ms/step - loss: 0.1114 - accuracy: 0.9629 - val_loss: 0.0949 - val_accuracy: 0.9565
# Epoch 7/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0910 - accuracy: 0.9749
# Epoch 00007: loss improved from 0.11139 to 0.09101, saving model to model.h5
# 29/28 [==============================] - 16s 552ms/step - loss: 0.0910 - accuracy: 0.9749 - val_loss: 0.0912 - val_accuracy: 0.9609
# Epoch 8/70
# 29/28 [==============================] - ETA: 0s - loss: 0.1011 - accuracy: 0.9727
# Epoch 00008: loss did not improve from 0.09101
# 29/28 [==============================] - 16s 539ms/step - loss: 0.1011 - accuracy: 0.9727 - val_loss: 0.1031 - val_accuracy: 0.9565
# Epoch 9/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0931 - accuracy: 0.9760
# Epoch 00009: loss did not improve from 0.09101
# 29/28 [==============================] - 15s 533ms/step - loss: 0.0931 - accuracy: 0.9760 - val_loss: 0.0639 - val_accuracy: 0.9696
# Epoch 10/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0968 - accuracy: 0.9716
# Epoch 00010: loss did not improve from 0.09101
# 29/28 [==============================] - 15s 532ms/step - loss: 0.0968 - accuracy: 0.9716 - val_loss: 0.0779 - val_accuracy: 0.9783
# Epoch 11/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0825 - accuracy: 0.9749
# Epoch 00011: loss improved from 0.09101 to 0.08247, saving model to model.h5
# 29/28 [==============================] - 16s 549ms/step - loss: 0.0825 - accuracy: 0.9749 - val_loss: 0.0906 - val_accuracy: 0.9696
# Epoch 12/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0729 - accuracy: 0.9749
# Epoch 00012: loss improved from 0.08247 to 0.07292, saving model to model.h5
# 29/28 [==============================] - 16s 552ms/step - loss: 0.0729 - accuracy: 0.9749 - val_loss: 0.0600 - val_accuracy: 0.9783
# Epoch 13/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0848 - accuracy: 0.9694
# Epoch 00013: loss did not improve from 0.07292
# 29/28 [==============================] - 15s 533ms/step - loss: 0.0848 - accuracy: 0.9694 - val_loss: 0.0842 - val_accuracy: 0.9652
# Epoch 14/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0853 - accuracy: 0.9716
# Epoch 00014: loss did not improve from 0.07292
# 29/28 [==============================] - 15s 533ms/step - loss: 0.0853 - accuracy: 0.9716 - val_loss: 0.1004 - val_accuracy: 0.9652
# Epoch 15/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0923 - accuracy: 0.9749
# Epoch 00015: loss did not improve from 0.07292
# 29/28 [==============================] - 15s 534ms/step - loss: 0.0923 - accuracy: 0.9749 - val_loss: 0.0589 - val_accuracy: 0.9739
# Epoch 16/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0810 - accuracy: 0.9749
# Epoch 00016: loss did not improve from 0.07292
# 29/28 [==============================] - 15s 534ms/step - loss: 0.0810 - accuracy: 0.9749 - val_loss: 0.0588 - val_accuracy: 0.9739
# Epoch 17/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0595 - accuracy: 0.9771
# Epoch 00017: loss improved from 0.07292 to 0.05946, saving model to model.h5
# 29/28 [==============================] - 16s 550ms/step - loss: 0.0595 - accuracy: 0.9771 - val_loss: 0.0975 - val_accuracy: 0.9609
# Epoch 18/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0818 - accuracy: 0.9738
# Epoch 00018: loss did not improve from 0.05946
# 29/28 [==============================] - 15s 534ms/step - loss: 0.0818 - accuracy: 0.9738 - val_loss: 0.0653 - val_accuracy: 0.9783
# Epoch 19/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0802 - accuracy: 0.9705
# Epoch 00019: loss did not improve from 0.05946
# 29/28 [==============================] - 15s 531ms/step - loss: 0.0802 - accuracy: 0.9705 - val_loss: 0.0504 - val_accuracy: 0.9783
# Epoch 20/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0671 - accuracy: 0.9814
# Epoch 00020: loss did not improve from 0.05946
# 29/28 [==============================] - 15s 534ms/step - loss: 0.0671 - accuracy: 0.9814 - val_loss: 0.0627 - val_accuracy: 0.9783
# Epoch 21/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0820 - accuracy: 0.9782
# Epoch 00021: loss did not improve from 0.05946
# 29/28 [==============================] - 16s 542ms/step - loss: 0.0820 - accuracy: 0.9782 - val_loss: 0.0454 - val_accuracy: 0.9870
# Epoch 22/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0583 - accuracy: 0.9814
# Epoch 00022: loss improved from 0.05946 to 0.05831, saving model to model.h5
# 29/28 [==============================] - 16s 552ms/step - loss: 0.0583 - accuracy: 0.9814 - val_loss: 0.0390 - val_accuracy: 0.9870
# Epoch 23/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0662 - accuracy: 0.9771
# Epoch 00023: loss did not improve from 0.05831
# 29/28 [==============================] - 16s 540ms/step - loss: 0.0662 - accuracy: 0.9771 - val_loss: 0.0470 - val_accuracy: 0.9783
# Epoch 24/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0749 - accuracy: 0.9727
# Epoch 00024: loss did not improve from 0.05831
# 29/28 [==============================] - 15s 532ms/step - loss: 0.0749 - accuracy: 0.9727 - val_loss: 0.0701 - val_accuracy: 0.9826
# Epoch 25/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0753 - accuracy: 0.9716
# Epoch 00025: loss did not improve from 0.05831
# 29/28 [==============================] - 16s 535ms/step - loss: 0.0753 - accuracy: 0.9716 - val_loss: 0.0635 - val_accuracy: 0.9783
# Epoch 26/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0542 - accuracy: 0.9803
# Epoch 00026: loss improved from 0.05831 to 0.05416, saving model to model.h5
# 29/28 [==============================] - 16s 555ms/step - loss: 0.0542 - accuracy: 0.9803 - val_loss: 0.0682 - val_accuracy: 0.9696
# Epoch 27/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0636 - accuracy: 0.9803
# Epoch 00027: loss did not improve from 0.05416
# 29/28 [==============================] - 16s 541ms/step - loss: 0.0636 - accuracy: 0.9803 - val_loss: 0.0768 - val_accuracy: 0.9609
# Epoch 28/70
# 29/28 [==============================] - ETA: 0s - loss: 0.1029 - accuracy: 0.9629
# Epoch 00028: loss did not improve from 0.05416
# 29/28 [==============================] - 15s 534ms/step - loss: 0.1029 - accuracy: 0.9629 - val_loss: 0.0734 - val_accuracy: 0.9739
# Epoch 29/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0801 - accuracy: 0.9738
# Epoch 00029: loss did not improve from 0.05416
# 29/28 [==============================] - 16s 536ms/step - loss: 0.0801 - accuracy: 0.9738 - val_loss: 0.0563 - val_accuracy: 0.9783
# Epoch 30/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0579 - accuracy: 0.9803
# Epoch 00030: loss did not improve from 0.05416
# 29/28 [==============================] - 16s 535ms/step - loss: 0.0579 - accuracy: 0.9803 - val_loss: 0.0940 - val_accuracy: 0.9696
# Epoch 31/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0745 - accuracy: 0.9771
# Epoch 00031: loss did not improve from 0.05416
# 29/28 [==============================] - 15s 532ms/step - loss: 0.0745 - accuracy: 0.9771 - val_loss: 0.0508 - val_accuracy: 0.9783
# Epoch 32/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0734 - accuracy: 0.9749
# Epoch 00032: loss did not improve from 0.05416
# 29/28 [==============================] - 15s 534ms/step - loss: 0.0734 - accuracy: 0.9749 - val_loss: 0.0588 - val_accuracy: 0.9739
# Epoch 33/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0782 - accuracy: 0.9782
# Epoch 00033: loss did not improve from 0.05416
# 29/28 [==============================] - 15s 533ms/step - loss: 0.0782 - accuracy: 0.9782 - val_loss: 0.0420 - val_accuracy: 0.9783
# Epoch 34/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0651 - accuracy: 0.9771
# Epoch 00034: loss did not improve from 0.05416
# 29/28 [==============================] - 15s 533ms/step - loss: 0.0651 - accuracy: 0.9771 - val_loss: 0.0431 - val_accuracy: 0.9783
# Epoch 35/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0839 - accuracy: 0.9760
# Epoch 00035: loss did not improve from 0.05416
# 29/28 [==============================] - 16s 536ms/step - loss: 0.0839 - accuracy: 0.9760 - val_loss: 0.0653 - val_accuracy: 0.9739
# Epoch 36/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0456 - accuracy: 0.9836
# Epoch 00036: loss improved from 0.05416 to 0.04558, saving model to model.h5
# 29/28 [==============================] - 16s 554ms/step - loss: 0.0456 - accuracy: 0.9836 - val_loss: 0.0728 - val_accuracy: 0.9826
# Epoch 37/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0624 - accuracy: 0.9803
# Epoch 00037: loss did not improve from 0.04558
# 29/28 [==============================] - 16s 535ms/step - loss: 0.0624 - accuracy: 0.9803 - val_loss: 0.0501 - val_accuracy: 0.9826
# Epoch 38/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0406 - accuracy: 0.9836
# Epoch 00038: loss improved from 0.04558 to 0.04056, saving model to model.h5
# 29/28 [==============================] - 16s 552ms/step - loss: 0.0406 - accuracy: 0.9836 - val_loss: 0.0329 - val_accuracy: 0.9913
# Epoch 39/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0799 - accuracy: 0.9793
# Epoch 00039: loss did not improve from 0.04056
# 29/28 [==============================] - 16s 536ms/step - loss: 0.0799 - accuracy: 0.9793 - val_loss: 0.0697 - val_accuracy: 0.9783
# Epoch 40/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0598 - accuracy: 0.9836
# Epoch 00040: loss did not improve from 0.04056
# 29/28 [==============================] - 16s 538ms/step - loss: 0.0598 - accuracy: 0.9836 - val_loss: 0.0609 - val_accuracy: 0.9783
# Epoch 41/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0549 - accuracy: 0.9836
# Epoch 00041: loss did not improve from 0.04056
# 29/28 [==============================] - 16s 537ms/step - loss: 0.0549 - accuracy: 0.9836 - val_loss: 0.0487 - val_accuracy: 0.9826
# Epoch 42/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0806 - accuracy: 0.9793
# Epoch 00042: loss did not improve from 0.04056
# 29/28 [==============================] - 16s 540ms/step - loss: 0.0806 - accuracy: 0.9793 - val_loss: 0.0418 - val_accuracy: 0.9913
# Epoch 43/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0650 - accuracy: 0.9793
# Epoch 00043: loss did not improve from 0.04056
# 29/28 [==============================] - 16s 541ms/step - loss: 0.0650 - accuracy: 0.9793 - val_loss: 0.0498 - val_accuracy: 0.9870
# Epoch 44/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0548 - accuracy: 0.9793
# Epoch 00044: loss did not improve from 0.04056
# 29/28 [==============================] - 16s 535ms/step - loss: 0.0548 - accuracy: 0.9793 - val_loss: 0.0344 - val_accuracy: 0.9913
# Epoch 45/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0379 - accuracy: 0.9847
# Epoch 00045: loss improved from 0.04056 to 0.03788, saving model to model.h5
# 29/28 [==============================] - 16s 551ms/step - loss: 0.0379 - accuracy: 0.9847 - val_loss: 0.0405 - val_accuracy: 0.9913
# Epoch 46/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0853 - accuracy: 0.9694
# Epoch 00046: loss did not improve from 0.03788
# 29/28 [==============================] - 16s 537ms/step - loss: 0.0853 - accuracy: 0.9694 - val_loss: 0.0505 - val_accuracy: 0.9913
# Epoch 47/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0526 - accuracy: 0.9836
# Epoch 00047: loss did not improve from 0.03788
# 29/28 [==============================] - 16s 536ms/step - loss: 0.0526 - accuracy: 0.9836 - val_loss: 0.0747 - val_accuracy: 0.9826
# Epoch 48/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0405 - accuracy: 0.9836
# Epoch 00048: loss did not improve from 0.03788
# 29/28 [==============================] - 16s 536ms/step - loss: 0.0405 - accuracy: 0.9836 - val_loss: 0.0713 - val_accuracy: 0.9870
# Epoch 49/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0862 - accuracy: 0.9716
# Epoch 00049: loss did not improve from 0.03788
# 29/28 [==============================] - 16s 539ms/step - loss: 0.0862 - accuracy: 0.9716 - val_loss: 0.0390 - val_accuracy: 0.9957
# Epoch 50/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0677 - accuracy: 0.9749
# Epoch 00050: loss did not improve from 0.03788
# 29/28 [==============================] - 16s 539ms/step - loss: 0.0677 - accuracy: 0.9749 - val_loss: 0.0381 - val_accuracy: 0.9826
# Epoch 51/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0635 - accuracy: 0.9749
# Epoch 00051: loss did not improve from 0.03788
# 29/28 [==============================] - 16s 538ms/step - loss: 0.0635 - accuracy: 0.9749 - val_loss: 0.0526 - val_accuracy: 0.9826
# Epoch 52/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0563 - accuracy: 0.9836
# Epoch 00052: loss did not improve from 0.03788
# 29/28 [==============================] - 15s 534ms/step - loss: 0.0563 - accuracy: 0.9836 - val_loss: 0.0396 - val_accuracy: 0.9826
# Epoch 53/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0537 - accuracy: 0.9847
# Epoch 00053: loss did not improve from 0.03788
# 29/28 [==============================] - 15s 534ms/step - loss: 0.0537 - accuracy: 0.9847 - val_loss: 0.0738 - val_accuracy: 0.9739
# Epoch 54/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0511 - accuracy: 0.9836
# Epoch 00054: loss did not improve from 0.03788
# 29/28 [==============================] - 15s 533ms/step - loss: 0.0511 - accuracy: 0.9836 - val_loss: 0.0396 - val_accuracy: 0.9826
# Epoch 55/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0621 - accuracy: 0.9782
# Epoch 00055: loss did not improve from 0.03788
# 29/28 [==============================] - 16s 536ms/step - loss: 0.0621 - accuracy: 0.9782 - val_loss: 0.0646 - val_accuracy: 0.9783
# Epoch 56/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0594 - accuracy: 0.9760
# Epoch 00056: loss did not improve from 0.03788
# 29/28 [==============================] - 15s 533ms/step - loss: 0.0594 - accuracy: 0.9760 - val_loss: 0.0603 - val_accuracy: 0.9783
# Epoch 57/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0498 - accuracy: 0.9858
# Epoch 00057: loss did not improve from 0.03788
# 29/28 [==============================] - 15s 532ms/step - loss: 0.0498 - accuracy: 0.9858 - val_loss: 0.0329 - val_accuracy: 0.9826
# Epoch 58/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0526 - accuracy: 0.9880
# Epoch 00058: loss did not improve from 0.03788
# 29/28 [==============================] - 15s 532ms/step - loss: 0.0526 - accuracy: 0.9880 - val_loss: 0.0576 - val_accuracy: 0.9783
# Epoch 59/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0741 - accuracy: 0.9814
# Epoch 00059: loss did not improve from 0.03788
# 29/28 [==============================] - 16s 536ms/step - loss: 0.0741 - accuracy: 0.9814 - val_loss: 0.0628 - val_accuracy: 0.9739
# Epoch 60/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0572 - accuracy: 0.9749
# Epoch 00060: loss did not improve from 0.03788
# 29/28 [==============================] - 16s 535ms/step - loss: 0.0572 - accuracy: 0.9749 - val_loss: 0.0531 - val_accuracy: 0.9739
# Epoch 61/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0798 - accuracy: 0.9749
# Epoch 00061: loss did not improve from 0.03788
# 29/28 [==============================] - 16s 538ms/step - loss: 0.0798 - accuracy: 0.9749 - val_loss: 0.0540 - val_accuracy: 0.9826
# Epoch 62/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0539 - accuracy: 0.9814
# Epoch 00062: loss did not improve from 0.03788
# 29/28 [==============================] - 16s 535ms/step - loss: 0.0539 - accuracy: 0.9814 - val_loss: 0.0493 - val_accuracy: 0.9783
# Epoch 63/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0587 - accuracy: 0.9782
# Epoch 00063: loss did not improve from 0.03788
# 29/28 [==============================] - 16s 536ms/step - loss: 0.0587 - accuracy: 0.9782 - val_loss: 0.0625 - val_accuracy: 0.9783
# Epoch 64/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0515 - accuracy: 0.9825
# Epoch 00064: loss did not improve from 0.03788
# 29/28 [==============================] - 15s 533ms/step - loss: 0.0515 - accuracy: 0.9825 - val_loss: 0.0330 - val_accuracy: 0.9826
# Epoch 65/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0593 - accuracy: 0.9782
# Epoch 00065: loss did not improve from 0.03788
# 29/28 [==============================] - 16s 537ms/step - loss: 0.0593 - accuracy: 0.9782 - val_loss: 0.0382 - val_accuracy: 0.9913
# Epoch 66/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0544 - accuracy: 0.9847
# Epoch 00066: loss did not improve from 0.03788
# 29/28 [==============================] - 16s 538ms/step - loss: 0.0544 - accuracy: 0.9847 - val_loss: 0.0494 - val_accuracy: 0.9783
# Epoch 67/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0544 - accuracy: 0.9836
# Epoch 00067: loss did not improve from 0.03788
# 29/28 [==============================] - 16s 535ms/step - loss: 0.0544 - accuracy: 0.9836 - val_loss: 0.0423 - val_accuracy: 0.9957
# Epoch 68/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0528 - accuracy: 0.9858
# Epoch 00068: loss did not improve from 0.03788
# 29/28 [==============================] - 16s 536ms/step - loss: 0.0528 - accuracy: 0.9858 - val_loss: 0.0329 - val_accuracy: 0.9913
# Epoch 69/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0620 - accuracy: 0.9803
# Epoch 00069: loss did not improve from 0.03788
# 29/28 [==============================] - 16s 537ms/step - loss: 0.0620 - accuracy: 0.9803 - val_loss: 0.0424 - val_accuracy: 0.9870
# Epoch 70/70
# 29/28 [==============================] - ETA: 0s - loss: 0.0620 - accuracy: 0.9793
# Epoch 00070: loss did not improve from 0.03788
# 29/28 [==============================] - 16s 537ms/step - loss: 0.0620 - accuracy: 0.9793 - val_loss: 0.0394 - val_accuracy: 0.9870

# %%
#load saved model
model=load_model('model.h5')

# %%
y_pred=model.predict(X_test,batch_size=32)

# %%
prediction=y_pred[0:10]
for index, probability in enumerate(prediction):
  if probability[1] > 0.5:
        plt.title('%.2f' % (probability[1]*100) + '% NonCOVID')
  else:
        plt.title('%.2f' % ((1-probability[1])*100) + '% COVID')
  plt.imshow(X_test[index])
  plt.show()

# %%
y_pred_bin = np.argmax(y_pred, axis=1)
y_test_bin = np.argmax(Y_test, axis=1)

# %%
import seaborn as sns
def plot_confusion_matrix(normalize):
  classes = ['COVID','NonCOVID']
  tick_marks = [0.5,1.5]
  cn = confusion_matrix(y_test_bin, y_pred_bin,normalize=normalize)
  sns.heatmap(cn,cmap='plasma',annot=True)
  plt.xticks(tick_marks, classes)
  plt.yticks(tick_marks, classes)
  plt.title('Confusion Matrix')
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.show()

print('Confusion Matrix without Normalization')
plot_confusion_matrix(normalize=None)

print('Confusion Matrix with Normalized Values')
plot_confusion_matrix(normalize='true')
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Confusion Matrix without Normalization
# Confusion Matrix with Normalized Values

# %%
fpr, tpr, thresholds = roc_curve(y_test_bin, y_pred_bin)
plt.plot(fpr, tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.rcParams['font.size'] = 12
plt.title('ROC curve for our model')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid(True)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test_bin, y_pred_bin))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99        90
#            1       0.99      0.99      0.99       140
#
#     accuracy                           0.99       230
#    macro avg       0.99      0.99      0.99       230
# weighted avg       0.99      0.99      0.99       230

# %%
plt.figure(figsize=(10,10))

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])
plt.show()

# %%
plt.figure(figsize=(10,10))

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])
plt.savefig('vgg_chest_loss.png')
plt.show()

# %%
shutil.copy2('/content/Xception_cxr.h5','/content/drive/My Drive/Untitled folder')
# Out:
# '/content/drive/My Drive/Untitled folder/Xception_cxr.h5'
